# %% [markdown]
# # Pokemon Stats Analysis
#
# In this notebook I will work with a database containing stats and other useful data, like types and legendary status, of 721 Pokemon (up to Generation VI). My goal will be to explore the information of all Pokemon and find trends, in order to finally get a list of the top 10 best non-legendary Pokemon and the top 5 legendary Pokemon.

# %% [markdown]
# ### Importing the data

# %%
# We import all the necessary libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# We set the style of the Seaborn graphs.
sns.set_style('darkgrid')

# We read the flat file containing the data and create a dataframe based on it.
pokemon = pd.read_csv('Pokemon.csv')

# We print the head of the dataframe to verify that the data was imported properly.
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# The data was imported correctly, so let's get a sample of 10 Pokemon from the dataset to see what information is available.
pokemon.sample(10)
# Out:
#        #                     Name    Type 1   Type 2  Total   HP  Attack  \
# 115  107               Hitmonchan  Fighting      NaN    455   50     105
# 178  164                  Noctowl    Normal   Flying    442  100      50
# 697  636                 Larvesta       Bug     Fire    360   55      85
# 757  687                  Malamar      Dark  Psychic    482   86      92
# 505  455                Carnivine     Grass      NaN    454   74     100
# 339  310  ManectricMega Manectric  Electric      NaN    575   70      75
# 174  160               Feraligatr     Water      NaN    530   85     105
# 172  158                 Totodile     Water      NaN    314   50      65
# 215  200               Misdreavus     Ghost      NaN    435   60      60
# 69    64                  Kadabra   Psychic      NaN    400   40      35
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 115       79       35      110     76           1      False
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Let's get some general info of the data frame.
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# There are 800 unique entries or Pokemon, with 13 variables categorizing them. We got the Name of the Pokemon, its primary and secondary type when it applies, the combat stats of the Pokemon (Total Stats, HP, Attack, Defense, Special Attack, Special Defense, and Speed), what generation it is from and whether it is legendary or not.

# %%
# There don't seem to be any missing values, but let's change the nulls from the Type 2 column into "None".
pokemon['Type 2'].fillna('None', inplace=True)
# Let's verify that the change was applied.
pokemon['Type 2'].isnull().sum()
# Out:
# 0

# %%
# Let's check for duplicates in the dataset.
pokemon.duplicated().sum()
# Out:
# 0

# %%
# Descriptive statistic summary of the stats of the Pokemon.
pokemon.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
# Let's visualize the distribution of the data.

# Distribution of the total stat sum of all Pokemon.
sns.displot(pokemon['Total'], bins=20, color = 'orange')
plt.show()

# %% [markdown]
# Most Pokemon have a stat Total of about 490-500.

# %%
# Number of Pokemon by Generation
plt.figure(figsize=(10, 6))
sns.countplot(x='Generation', data=pokemon)
plt.xlabel('Generation')
plt.ylabel('Number of Pokemon')
plt.title('Pokemon by Generation')
plt.show()

# %% [markdown]
# Generation 1 is the generation most represented in the dataset, followed closely by Gen V and Gen III. The least represented Generation is the 6th.

# %%
# Counts of legendary vs non-legendary pokemon.
plt.figure(figsize=(10, 6))
sns.countplot(x='Legendary', data=pokemon, order=[True, False])
plt.xlabel('Legendary')
plt.ylabel('Number of Pokemon')
plt.title('Pokemon by Legendary status')
plt.show()

# %%
# Distribution of Attack and Defense, relationship between both.
sns.jointplot(data=pokemon, x='Attack', y='Defense',kind='reg')
plt.show()

# %% [markdown]
# There seems to be a positive relationship between Attack and Defense, when one goes up, the other one increases as well.

# %%
# Attack and Defense by primary Type.
plt.figure(figsize=(10,10))
sns.scatterplot(data=pokemon, x='Attack', y='Defense',hue='Type 1')
plt.show()

# %% [markdown]
# Most Pokemon have an Attack of about 60 to 70, while most Pokemon have a Defense of around 55 to 65.
# Looking at the data, it would seem that Normal and Bug Pokemon are often the worst performing in these two attributes, while Dragon, Rock, Ghost and Steel seem to be especially strong.

# %%
# Distribution of Special Attack and Special Defense, relationship between both.
sns.jointplot(data=pokemon, x='Sp. Atk', y='Sp. Def', kind='reg')
plt.show()

# %% [markdown]
# The relationship between Sp. Atk and Sp. Def is almost identical to that of regular Attack and Defense.

# %%
# Special Attack and Special Defense by Primary Type
plt.figure(figsize=(10,10))
sns.scatterplot(data=pokemon, x='Sp. Atk', y='Sp. Def', hue='Type 1')
plt.show()

# %% [markdown]
# Special Attack seems to vary a lot from type to type, with a lot of Normal Pokemon having Sp. Atk below 50, Water Pokemon being evenly distributed from about 55 to 85 Sp. Atk. Special Defense is less diverse, with most Pokemon having this stat at about 60 to 70. Once again, Normal and Bug Pokemon seem to be very weak in these attributes, and there seem to be less strong outliers in the data.

# %%
# Let's see the distribution of the Speed stat.
sns.displot(pokemon['Speed'], bins = 20)
plt.title('Speed stat distribution')
plt.show()

# %% [markdown]
# Most Pokemon are moderately slow, with most having a speed of about 55 to 60. Speed is king in competitive Pokemon, so those few over 100 are going to be great performers in a competitive environment.

# %%
# Distribution of the HP stat.
sns.displot(pokemon['HP'], color = 'red', bins=20)
plt.title('HP stat distribution')
plt.show()

# %% [markdown]
# Most Pokemon have base HP of about 60 to 70.

# %%
# In order to get the correlation between stats, a new dataframe containing only the 6 stats will be created.
corr_df = pokemon[['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]

# Stat correlation map
plt.rcParams['figure.figsize']=(15,9)
heat_map = sns.heatmap(corr_df.corr(), annot = True, linewidths=1, cmap='Blues')
heat_map.set_title(label='Stat Correlation Map', fontsize=25)
heat_map;

# %% [markdown]
# The closest correlations among stats are between Defense and Special Defense and Special Defense and Special Attack. Special Attack and Speed seem to have a relatively high correlation as well.
#
# Speed and Defense are barely correlated at all, and the relationship between Speed and HP is negligible as well.

# %% [markdown]
# ### Defining competitiveness of a Pokemon
#
# While Pokemon have 6 stats, when it comes to high level competitive play some stats are more useful than others. This is why a simple sum of all stats, like the one in the dataset, would be useless in order to find the best Pokemon.
#
# While there are special cases and strategies where this does not apply, Speed is usually the most important stat of a Pokemon. Making your move first can be the difference between life and death.
#
# Out of curiosity, let's see what the top 5 fastest Pokemon are.

# %%
# We create a data frame with the top 5 fastest Pokemon. This one includes both legendary and non-legendary
fastest5_all = pokemon.nlargest(5, 'Speed')
fastest5_all
# Out:
#        #                       Name   Type 1  Type 2  Total  HP  Attack  \
# 431  386          DeoxysSpeed Forme  Psychic    None    600  50      95
# 315  291                    Ninjask      Bug  Flying    456  61      90
# 71    65      AlakazamMega Alakazam  Psychic    None    590  55      50
# 154  142  AerodactylMega Aerodactyl     Rock  Flying    615  80     135
# 428  386         DeoxysNormal Forme  Psychic    None    600  50     150
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 431       90       95       90    180           3       True
# 315       45       50       50    160           3      False
# 71        65      175       95    150           1      False
# 154       85       70       95    150           1      False
# 428       50      150       50    150           3       True

# %% [markdown]
# The fastest Pokemon is Deoxys, a Gen III legendary, in its Speed form. It has a Speed of 180. However, Deoxys in its normal form has 150. Since Legendary Pokemon are mostly banned from tournaments either way, let's see the top 10 fastest Pokemon that are not legendary.

# %%
# Data frame of the top 10 non-legendary fastest Pokemon.
fastest5_reg = pokemon[pokemon['Legendary'] == False]
fastest5_reg = fastest5_reg.nlargest(10, 'Speed')
fastest5_reg
# Out:
#        #                       Name    Type 1    Type 2  Total  HP  Attack  \
# 315  291                    Ninjask       Bug    Flying    456  61      90
# 71    65      AlakazamMega Alakazam   Psychic      None    590  55      50
# 154  142  AerodactylMega Aerodactyl      Rock    Flying    615  80     135
# 19    15      BeedrillMega Beedrill       Bug    Poison    495  65     150
# 275  254      SceptileMega Sceptile     Grass    Dragon    630  70     110
# 678  617                   Accelgor       Bug      None    495  80      70
# 109  101                  Electrode  Electric      None    480  60      50
# 339  310    ManectricMega Manectric  Electric      None    575  70      75
# 476  428        LopunnyMega Lopunny    Normal  Fighting    580  65     136
# 102   94          GengarMega Gengar     Ghost    Poison    600  60      65
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 315       45       50       50    160           3      False
# ...

# %%
# We visualize the decrease of Speed in the top 10.
sns.pointplot(data=fastest5_reg, y="Speed",x="Name")
plt.xticks(rotation=45)
plt.ylim(120, 170)
plt.show()

# %% [markdown]
# The top 10 fastest tournament legal Pokemon range between 160 and 130 speed. We shall see if any of these make it into the top 10 most competitive Pokemon.
#
# #### Pokemon Stats Ranking
#
# After investigating on the Internet and speaking with some friends well versed in competitive Pokemon, I defined that the order of importance of stats is as follows*:
#
# 1. Speed
# 2. HP
# 3. Sp. Atk
# 4. Sp. Def
# 5. Attack
# 6. Defense
#
# *: I am not a Pokemon expert, please don't come after me as I am just doing this to practice my Python skills.

# %% [markdown]
# ### The equation to quantify competitiveness.
#
# With the importance of each stat in mind, an equation had to be designed to portray the weight of each stat accordingly. This equation was designed to keep all stats relevant and avoid the result to be too high.
#
# Each stat would be multiplied according to importance:
# * Speed = 1.06
# * HP = 1.03
# * Sp. Atk = 1.00
# * Sp. Def = 1.00
# * Attack = 0.99
# * Defense = 0.98
#
# This would then be divided by 10.
#
# ## Rating by competitiveness

# %%
# We create a new column of the Pokemon DataFrame with the competitiveness rating.
pokemon['Competitiveness'] = ((pokemon['Speed'] * 1.06) + (pokemon['HP'] * 1.03) + (pokemon['Sp. Atk'] * 1.00) 
                             + (pokemon['Sp. Def'] * 1.00) + (pokemon['Attack'] * 0.99) + (pokemon['Defense'] * 0.98)) / 10

# %%
# We create a data frame with the top 10 most competitive Pokemon.
top10competitive = pokemon[pokemon['Legendary'] == False]
top10competitive = top10competitive.nlargest(10, 'Competitiveness')
top10competitive
# Out:
#        #                       Name  Type 1   Type 2  Total   HP  Attack  \
# 409  373    SalamenceMega Salamence  Dragon   Flying    700   95     145
# 494  445      GarchompMega Garchomp  Dragon   Ground    700  108     170
# 413  376    MetagrossMega Metagross   Steel  Psychic    700   80     145
# 268  248    TyranitarMega Tyranitar    Rock     Dark    700  100     164
# 313  289                    Slaking  Normal     None    670  150     160
# 141  130      GyaradosMega Gyarados   Water     Dark    640   95     155
# 8      6  CharizardMega Charizard Y    Fire   Flying    634   78     104
# 7      6  CharizardMega Charizard X    Fire   Dragon    634   78     130
# 283  260      SwampertMega Swampert   Water   Ground    635  100     150
# 275  254      SceptileMega Sceptile   Grass   Dragon    630   70     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Competitiveness
# 409      130      120       90    120           3      False           70.600
# ...

# %% [markdown]
# The best Pokemon for competitive play, according to the equation, is Mega Salamence, a Gen III Dragon/Psychic. The only non-Mega Evolved Pokemon in the entire list is Slaking, which is to be commended. Mega Sceptile, who was among the top 10 fastest Pokemon, barely made the cut.

# %%
# We create a data frame with the top 5 most competitive Legendary Pokemon.
top10legendary = pokemon[pokemon['Legendary'] == True].nlargest(5, 'Competitiveness')
top10legendary
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 164  150    MewtwoMega Mewtwo Y  Psychic      None    780  106     150
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 422  382    KyogrePrimal Kyogre    Water      None    770  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Competitiveness
# 164       70      194      120    140           1       True           78.868
# 163      100      154      100    130           1       True           78.708
# 426      100      180      100    115           3       True           78.625
# 422       90      180      160     90           3       True           77.510
# 424      160      150       90     90           3       True           77.340

# %% [markdown]
# Whichever way you cut it, Mega Mewtwo is the best Legendary Pokemon, followed by the three Legendaries of Gen III. It is surprising to see that Gen III dominates both rankings.

# %% [markdown]
# ## Competitiveness, excluding Megas, Primals and Legendaries
#
# Analyzing the dataset, I realized we can exclude Megas by using the .str.contains() method. Let's do the same that we did before, but filtering out "Mega " and legendaries. The final product will be the top 10 non-Mega and non-Legendary Pokemon.

# %%
regular_comp = pokemon[~pokemon['Name'].str.contains('Mega ')]
regular_comp = regular_comp[regular_comp['Legendary'] == False]
top10regular_comp = regular_comp.nlargest(10, 'Competitiveness')
top10regular_comp
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 313  289                  Slaking   Normal      None    670  150     160
# 716  648  MeloettaPirouette Forme   Normal  Fighting    600  100     128
# 493  445                 Garchomp   Dragon    Ground    600  108     130
# 715  648       MeloettaAria Forme   Normal   Psychic    600  100      77
# 165  151                      Mew  Psychic      None    600  100     100
# 271  251                   Celebi  Psychic     Grass    600  100     100
# 548  490                  Manaphy    Water      None    600  100     100
# 408  373                Salamence   Dragon    Flying    600   95     135
# 696  635                Hydreigon     Dark    Dragon    600   92     105
# 546  488                Cresselia  Psychic      None    600  120      70
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Competitiveness
# 313      100       95       65    100           3      False           67.690
# ...

# %% [markdown]
# Slaking is undoubtedly the most competitive non-Mega tournament legal Pokemon, leaping ahead of the rest by 7 full points.

# %% [markdown]
# ## Closing thoughts
#
# Gen III is amazing. It was interesting to see how much Mega status enhanced the competitiveness of a Pokemon. It was commendable to see Slaking hold its own against other 9 Megas in the top 10 that included this tier. The gap between Slaking and the second regular Pokemon, Meloetta in Pirouette Forme, is an entire 7 points. I look forward to refining the formula in the future and see how the top 10 changes according to the ponderation.
